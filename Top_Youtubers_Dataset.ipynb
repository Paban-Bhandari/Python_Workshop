# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv('data/Top Youtubers Dataset.csv', encoding='ISO-8859-1')
print(df)
# Out:
#      Rank                                       Youtuber  Subscribers  \
# 0       1                                        MrBeast    284000000
# 1       2                                       T-Series    268000000
# 2       3                                 YouTube Movies    181000000
# 3       4                     Cocomelon - Nursery Rhymes    177000000
# 4       5                                      SET India    174000000
# ..    ...                                            ...          ...
# 995   996  Peppa Pig em Português Brasil - Canal Oficial     14500000
# 996   997                                    Bie The Ska     14500000
# 997   998                                        Cyprien     14500000
# 998   999                                  YANA CHIRKINA     14500000
# 999  1000         Tayo Bus Kecil - Tayo Bahasa Indonesia     14500000
#
#       Video Views  Video Count          Category  Started
# 0    5.240290e+10          803     Entertainment     2012
# ...

# %%
#total engagement
df['total_engagement'] = df[['Subscribers', 'Video Views', 'Video Count']].sum(axis=1)
print(df.head())
# Out:
#    Rank                    Youtuber  Subscribers   Video Views  Video Count  \
# 0     1                     MrBeast    284000000  5.240290e+10          803
# 1     2                    T-Series    268000000  2.586240e+11        21237
# 2     3              YouTube Movies    181000000  0.000000e+00            0
# 3     4  Cocomelon - Nursery Rhymes    177000000  1.828810e+11         1188
# 4     5                   SET India    174000000  1.653950e+11       139720
#
#            Category  Started  total_engagement
# 0     Entertainment     2012      5.268690e+10
# 1             Music     2006      2.588920e+11
# 2  Film & Animation     2015      1.810000e+08
# 3         Education     2006      1.830580e+11
# 4             Shows     2006      1.655691e+11

# %%
# Group by Category and sum the Subscribers
category_subscribers = df.groupby('Category')['Subscribers'].sum().reset_index()
print(category_subscribers)

# Plotting
plt.figure(figsize=(10, 6))
plt.bar(category_subscribers['Category'], category_subscribers['Subscribers'], color='skyblue')
plt.title('Total Subscribers by Category')
plt.xlabel('Category')
plt.ylabel('Total Subscribers (in billions)')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
#                  Category  Subscribers
# 0        Autos & Vehicles     44200000
# 1                  Comedy   1732400000
# 2               Education   1278700000
# 3           Entertainment   6732200000
# 4        Film & Animation   1473900000
# 5                  Gaming   2181800000
# 6           Howto & Style    678300000
# 7                  Movies     59400000
# 8                   Music   5093800000
# 9         News & Politics    662600000
# 10  Nonprofits & Activism     63200000
# 11         People & Blogs   3792300000
# 12         Pets & Animals    119800000
# 13   Science & Technology    363500000
# 14                  Shows    605200000
# 15                 Sports    457700000
# 16               Trailers     85500000

# %%
#Top 10 YouTubers by Subscribers
top_10_youtubers = df.nlargest(10, 'Subscribers')
print(top_10_youtubers)

# Plotting
plt.figure(figsize=(10, 6))
plt.bar(top_10_youtubers['Youtuber'], top_10_youtubers['Subscribers'], color='skyblue')
plt.title('Top 10 YouTubers by Subscribers')
plt.xlabel('YouTuber')
plt.ylabel('Subscribers')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
#    Rank                    Youtuber  Subscribers   Video Views  Video Count  \
# 0     1                     MrBeast    284000000  5.240290e+10          803
# 1     2                    T-Series    268000000  2.586240e+11        21237
# 2     3              YouTube Movies    181000000  0.000000e+00            0
# 3     4  Cocomelon - Nursery Rhymes    177000000  1.828810e+11         1188
# 4     5                   SET India    174000000  1.653950e+11       139720
# 5     6           ? Kids Diana Show    123000000  1.039730e+11         1230
# 6     7                       Music    121000000  0.000000e+00            0
# 7     8               Vlad and Niki    120000000  9.164619e+10          730
# 8     9                 Like Nastya    116000000  1.013940e+11          886
# 9    10                   PewDiePie    111000000  2.932116e+10         4767
#
#            Category  Started  total_engagement
# 0     Entertainment     2012      5.268690e+10
# ...

# %%
#Average Video Count by Category
category_avg_video_count = df.groupby('Category')['Video Count'].mean().reset_index()
print(category_avg_video_count)

plt.figure(figsize=(10, 6))
plt.bar(category_avg_video_count['Category'], category_avg_video_count['Video Count'], color='lightgreen')
plt.title('Average Video Count by Category')
plt.xlabel('Category')
plt.ylabel('Average Video Count')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
#                  Category    Video Count
# 0        Autos & Vehicles    2118.500000
# 1                  Comedy    1418.929577
# 2               Education    3800.634146
# 3           Entertainment   13954.639405
# 4        Film & Animation    3742.644444
# 5                  Gaming    4721.315217
# 6           Howto & Style    2731.714286
# 7                  Movies    4905.000000
# 8                   Music    2946.296512
# 9         News & Politics  156658.857143
# 10  Nonprofits & Activism  112003.000000
# 11         People & Blogs   12432.644737
# 12         Pets & Animals    2128.000000
# 13   Science & Technology    2362.666667
# 14                  Shows   34366.153846
# 15                 Sports   11776.294118
# 16               Trailers    7012.500000

# %%
category_video_count = df.groupby('Category')['Video Count'].sum().reset_index()
total_video_count = category_video_count['Video Count'].sum()
category_video_count['Percentage'] = (category_video_count['Video Count'] / total_video_count) * 100
category_video_count = category_video_count.sort_values(by='Percentage', ascending=False)
print(category_video_count)

# Pie Chart
plt.figure(figsize=(10, 10))
plt.pie(
    category_video_count['Video Count'],
    labels=category_video_count['Category'],
    autopct='%1.1f%%',
    startangle=140
)
plt.title('Category Distribution by Video Count')
plt.tight_layout()
plt.show()
# Out:
#                  Category  Video Count  Percentage
# 9         News & Politics      4386448   35.318038
# 3           Entertainment      3753798   30.224177
# 11         People & Blogs      1889762   15.215656
# 8                   Music       506763    4.080266
# 14                  Shows       446760    3.597144
# 5                  Gaming       434361    3.497312
# 10  Nonprofits & Activism       224006    1.803612
# 15                 Sports       200197    1.611911
# 4        Film & Animation       168419    1.356047
# 2               Education       155826    1.254653
# 1                  Comedy       100744    0.811153
# 6           Howto & Style        76488    0.615853
# 13   Science & Technology        35440    0.285350
# 16               Trailers        14025    0.112924
# 12         Pets & Animals        12768    0.102803
# 7                  Movies         9810    0.078986
# 0        Autos & Vehicles         4237    0.034115
